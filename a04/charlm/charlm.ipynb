# %% [markdown]
# # Assignment 4, task 3
#
# In this task, you are going to implement a character model based on the Transformer architecture, starting from the provided skeleton. It is useful to first do exercise 2 before starting on this task.
#
# The model you are going to implement here will have a context of 32 characters, i.e. it will consider the preceding 32 characters when estimating the probabilities of the possible character coming next. Due to the clever transformer architecture, the model will have less than 50,000 trainable parameters. As a comparison, the simpler model in exercise 2 only had a context of 8 characters but had more than 300,000 trainable parameters.

# %%
# First run this cell
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
from datetime import datetime
import math

# %% [markdown]
# We need to map every type of input item (every character, in our case) to a unique ID number. Since we are not sure which characters will appear in our training text, we are going to create new IDs as we encounter new kinds of characters we haven't seen before.

# %%
char_to_id = {}  # Dictionary to store character-to-ID mapping
id_to_char = []  # List to store characters in their ID ordering
PADDING_SYMBOL = '<PAD>'
char_to_id[PADDING_SYMBOL] = 0
id_to_char.append(PADDING_SYMBOL)

# %% [markdown]
# We now define a class 'CharDataset' that extends the predefined 'Dataset' class.Compared to exercise 2, we will create data points in a slightly different way.
#
# The init function reads a training text and splits it up into chunks $n$ characters long. From each chunk, $n$ data points with a corresponding label will be created, as in the following example:
#
# Suppose $n=8$. From a chunk $[4,5,9,11,7,7,2,12]$ with 14 being the next character ID, the following data points and labels will be formed (0 is the padding symbol):
#
# |          Data point | Label |
# | ------------------: | ----: |
# |   [4,0,0,0,0,0,0,0] |     5 |
# |   [4,5,0,0,0,0,0,0] |     9 |
# |   [4,5,9,0,0,0,0,0] |    11 |
# |  [4,5,9,11,0,0,0,0] |     7 |
# |  [4,5,9,11,7,0,0,0] |     7 |
# |  [4,5,9,11,7,7,0,0] |     2 |
# |  [4,5,9,11,7,7,2,0] |    12 |
# | [4,5,9,11,7,7,2,12] |    14 |
#
# This way, the model will learn to infer the next character even if the context is shorter than $n$. This is a very useful feature, particularly in 'real' language models, where the known context often is shorter than the maximal context length.

# %%
class CharDataset(Dataset):

    def __init__(self, file_path, n):
        self.datapoints = []
        self.labels = []
        chars = []
        try:
            # First read the dataset to find all the unique characters
            with open(file_path, 'r', encoding='utf-8') as f:
                contents = f.read()
            # YOUR CODE HERE
            for char in contents:
                if char not in char_to_id:
                    char_to_id[char] = len(id_to_char)
                    id_to_char.append(char)
                chars.append(char_to_id[char])
            # Then go through all the chars and chunk them up into datapoints
            k = 0
            while k < len(chars)-n:
                for i in range(1, n+1):
                    self.datapoints.append([c for c in chars[k:i+k]+[0]*(n-i)])
                    self.labels.append(chars[i+k])
                k += n
        except FileNotFoundError:
            print(f"File not found: {file_path}")
        except Exception as e:
            print(f"An error occurred: {e}")

    def __len__(self):
        return len(self.datapoints)

    def __getitem__(self, idx):
        idx = idx % len(self.datapoints)
        return torch.tensor(self.datapoints[idx]), torch.tensor(self.labels[idx], dtype=torch.long)

# %%
# Verify
# Max context is 32 characters long.
dataset = CharDataset('lang-eng-labs/exercise/HP_book_1.txt', 32)
d63, l63 = dataset[63]
d1048575, l1048575 = dataset[1048575]
d1048576, l1048576 = dataset[1048576]
print(d63[16].item() == l63.item())
print(d63[4].item() == l1048575.item())
print(sum(d1048576[1:]).item() == 0)
# Out:
# True
# True
# True

# %% [markdown]
# The **self-attention** computation is at the core of the Transformer architecture. It is important to get this computation efficient (i.e. vectorized), since it involves many matrix operations that would be very slow if implemented by Python loops.
#
# The input to the self-attention computation is a tensor containing a vector for each input token, and the output is a tensor of the same dimensions, containing the contextualized versions of the input tokens (see Lecture 9 and the textbook, chapters 10.1 and 10.2).
#
# Your task is to fill in the missing pieces below. Look for "REPLACE WITH YOUR CODE" and "YOUR CODE HERE".

# %%
class MultiHeadSelfAttention(nn.Module):
    """
    Calculates self-attention according to [Vaswani et al., NeurIPS, 2017]
    """

    def __init__(self, hidden_size, number_of_attention_heads):
        super().__init__()
        # The number of attention heads cannot be more than the hidden size
        assert hidden_size > number_of_attention_heads

        self.number_of_attention_heads = number_of_attention_heads
        # Divide the hidden_size roughly equal over the different heads
        self.attention_head_size = int(hidden_size / number_of_attention_heads)
        self.all_head_size = number_of_attention_heads * self.attention_head_size

        # Mapping from input to the query, key, and, value vectors
        self.query = nn.Linear(hidden_size, self.all_head_size, bias=False)
        self.key = nn.Linear(hidden_size, self.all_head_size, bias=False)
        self.value = nn.Linear(hidden_size, self.all_head_size, bias=False)

        self.final = nn.Linear(self.all_head_size, hidden_size, bias=False)

    def reshape_for_multihead_attention(self, x):
        # x has the shape (batch_size, seq_length, hidden_size)
        B, S, _ = x.shape

        # but we want to split the representation of each token into 'number_of_heads' parts:
        x = x.reshape(B, S, self.number_of_attention_heads,
                      self.attention_head_size)

        # and treat each part separately. Thus, we need the final tensor to have shape
        # (batch_size, number_of_heads, seq_length, attention_head_size)
        return x.permute(0, 2, 1, 3)

    def forward(self, hidden_states):
        # All of the tensors below will have the shape (batch_size, seq_length, hidden_size)
        query_all_heads = self.query(hidden_states)
        key_all_heads = self.key(hidden_states)
        value_all_heads = self.value(hidden_states)

        # All of the tensors below will have the shape (batch_size, number_of_heads, seq_length, attention_head_size)
        Q = self.reshape_for_multihead_attention(query_all_heads)
        K = self.reshape_for_multihead_attention(key_all_heads)
        V = self.reshape_for_multihead_attention(value_all_heads)

        # attention_scores will have the shape(batch_size, number_of_heads, seq_length, seq_length)
        attention_scores = torch.matmul(
            Q, K.transpose(-1, -2))  # REPLACE WITH YOUR CODE

        # Scale to reduce variance
        # REPLACE WITH YOUR CODE
        attention_scores /= math.sqrt(self.attention_head_size)

        # Use softmax to turn the attention scores into probabilities.
        # We want zero scores to be zero probabilities -- hence we turn
        # zero scores into -infinity before the softmax exponentiation.

        # YOUR CODE HERE
        attention_probs = nn.functional.softmax(
            attention_scores, dim=-1)  # REPLACE WITH YOUR CODE

        # Now produce the contextualized vectors for each head
        # The tensor below will have shape (batch_size, number_of_heads, seq_length, head_size)
        self_attention_all_heads_separately = torch.matmul(
            attention_probs, V)  # REPLACE WITH YOUR CODE

        # For each token, we now want to bring together the representation coming from each head.
        # The 'self_attention' tensor below should have the shape
        # (batch size, seq_length_, self.all_heads_size)
        self_attention = self_attention_all_heads_separately.permute(
            # REPLACE WITH YOUR CODE
            0, 2, 1, 3).reshape(-1, hidden_states.shape[1], self.all_head_size)

        # Finally, make sure that the output has the correct dimensions (batch_size,seq_length,hidden_size)
        return self.final(self_attention)

# %% [markdown]
# After the self-attention computation, the Transformer encoder block contains layer-normalization computations and a feed-forward layer. The code is given below.

# %%
class PositionwiseFFN(nn.Module):
    """
    The position-wise FFN that follows after the self-attention
    computation.
    """

    def __init__(self, hidden_size, dropout_prob):
        super().__init__()
        self.fc1 = nn.Linear(hidden_size, hidden_size, bias=True)
        self.fc2 = nn.Linear(hidden_size, hidden_size, bias=True)
        self.dropout = nn.Dropout(dropout_prob)
        for module in (self.fc1, self.fc2):
            nn.init.kaiming_normal_(module.weight)
            nn.init.constant_(module.bias, 0.)

    def forward(self, x):
        return self.fc2(self.dropout(torch.relu(self.fc1(x))))


class EncoderBlock(nn.Module):
    """
    Transformer encoder block.

    This version differs from the original version in  [Vaswani et al. NeurIPS 2017],
    and applies the LayerNorm before the self-attention, and before the FFN, as this
    has proved to be beneficial (see [Nguyen and Salazar 2019]).
    """

    def __init__(self, hidden_size, number_of_attention_heads, dropout_prob):
        super().__init__()
        self.attn = MultiHeadSelfAttention(
            hidden_size, number_of_attention_heads)
        self.ffn = PositionwiseFFN(hidden_size, dropout_prob)
        self.dropout = nn.Dropout(dropout_prob)
        self.ln1 = nn.LayerNorm(hidden_size)
        self.ln2 = nn.LayerNorm(hidden_size)

    def forward(self, x):
        x1 = self.ln1(x)
        x2 = x + self.dropout(self.attn(x1))
        x3 = self.ln2(x2)
        x4 = x2 + self.dropout(self.ffn(x3))
        return x4

# %% [markdown]
# Here is the actual character-based language model, which uses the Transformer implementation above.

# %%
# ============= Hyper-parameters for training ============== #

class Config:
    number_of_transformer_encoders = 1
    number_of_attention_heads = 1
    hidden_size = 64
    dropout_prob = 0.1
    batch_size = 64
    learning_rate = 0.0003
    weight_decay = 0.000001
    no_of_epochs = 100


MAXLEN = 32   # This is the number of characters we will consider when
# predicting the next character

# ======================= The model ======================= #


class CharLM(nn.Module):

    def __init__(self, config, no_of_input_chars):
        super(CharLM, self).__init__()
        self.config = config
        self.embed = nn.Embedding(no_of_input_chars, config.hidden_size)
        # Make sure that the padding symbol (which has ID 0) is embedded
        # as a vector of 0s.
        self.embed.weight.data[0].fill_(0)
        self.positional = nn.Parameter(
            torch.randn(1, MAXLEN, config.hidden_size))
        modules = [EncoderBlock(config.hidden_size,
                                config.number_of_attention_heads,
                                config.dropout_prob) for _ in range(config.number_of_transformer_encoders)]
        self.transformers = nn.ModuleList(modules)
        self.final = nn.Linear(config.hidden_size*MAXLEN, no_of_input_chars)

    def forward(self, x):
        number_of_datapoints = x.shape[0]
        # First create a mask distinguishing 0 from positive word IDs
        non_zero_mask = (x != 0)
        word_embeddings = self.embed(x)
        # Add positional vectors in all non-padded positions
        pos = self.positional.expand_as(word_embeddings)
        pos = pos * non_zero_mask.unsqueeze(-1).float()
        t = word_embeddings + pos
        # Then apply the transformers and make a final prediction at the end
        for transf in self.transformers:
            t = transf(t)
        flattened_transf = t.reshape(number_of_datapoints, 1, -1)
        result = self.final(torch.tanh(flattened_transf))
        return result

# %%
# ======================= Training ======================= #

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Running on", device)

config = Config()
training_dataset = CharDataset('lang-eng-labs/exercise/HP_book_1.txt', 32)
print("There are", len(training_dataset), "datapoints and",
      len(id_to_char), "unique characters in the dataset")
training_loader = DataLoader(training_dataset, batch_size=config.batch_size)

charlm = CharLM(config, len(id_to_char)).to(device)
criterion = nn.CrossEntropyLoss()
charlm_optimizer = optim.Adam(charlm.parameters(), lr=config.learning_rate)

charlm.train()
print(datetime.now().strftime("%X"), "Training starts")
for epoch in range(config.no_of_epochs):
    iteration = 0
    for input_tensor, label in training_loader:
        input_tensor, label = input_tensor.to(device), label.to(device)
        charlm_optimizer.zero_grad()
        logits = charlm(input_tensor).to(device)
        loss = criterion(logits.squeeze(1), label)
        loss.backward()
        charlm_optimizer.step()
        iteration += 1

    print(datetime.now().strftime("%X"), "End of epoch",
          epoch+1, ", loss=", loss.detach().item())
    charlm.eval()
    # Generate 50 characters starting from the input text
    try:
        char_list = list("he took out his wand and"[-MAXLEN:])
        for i in range(300):
            input_tensor = torch.tensor([char_to_id[c] for c in char_list] + [
                                        char_to_id[PADDING_SYMBOL]]*(MAXLEN-len(char_list))).unsqueeze(0).to(device)
            logits = charlm(input_tensor).squeeze().to(device)
            _, new_character_tensor = logits.topk(1)
            new_character = id_to_char[new_character_tensor.detach().item()]
            print(new_character, end='')
            if len(char_list) == MAXLEN:
                char_list.pop(0)
            char_list.append(new_character)
        print()
    except KeyError:
        continue
    charlm.train()
# Out:
# Running on cuda
# There are 442720 datapoints and 81 unique characters in the dataset
# 20:44:42 Training starts
# 20:44:59 End of epoch 1 , loss= 2.7797327041625977
#   anng ana a the yele ana trin y ana and to o ana ulye y ana to the here a anury anld ge ary ana te the ana a tinng the a ana ye t ana there ye a anud and t he ana tey conu a foule to the here a ana sind ang ton he a ana uly to anule t to herere a any anan ging to onun a fut inin the a ana try a ano
# 20:45:17 End of epoch 2 , loss= 2.507356882095337
#  se se anlel offere foully toun the ane anind s and here founly foully the tooure se san ane fone fone fon there fore st fully salle se saned saning to ang and the arin so sally se sallye sing se fone tone the the ane sing se foned an toun se sally sing the ane fine sering toung fing the an touly se
# 20:45:33 End of epoch 3 , loss= 2.2125518321990967
#  sing sing anle se fonere stout y salle sally, ally, an an and the wand sand and off somery and sing of sered ane and so the fing sally foully and waring to and and sing the fone ser and sto and to sally ane sally sing oully se alle and the wand san aner foully, and san ally sing the ane and wand an
# 20:45:48 End of epoch 4 , loss= 2.252694845199585
#  sing seaing to sthe salle fore fone ste to fre fomey and and to the se and youllle -- and an wary fouge and the sand sing one sto and saing the fon yould the sand and and and the wand saing to sto fre se saing the fonere st and and to the se faing to fulle sthe saing to saing to saing the pering to
# 20:46:04 End of epoch 5 , loss= 2.1766042709350586
#  said Harry fooke staing to the saing the said Harry fof and and the fore se saide saing to sthe said Harry fore and to and the fone saing and the saing and Harry fower of and saing to the saing and Harry said Harry fooke fine sto stut saing the ye fore sto fere se fored and of to the saing the said
# 20:46:20 End of epoch 6 , loss= 2.0554420948028564
#  and sid Harry fore some on said Harry said Harry foor and saing the sing and Ron and fing and the fore sto to the staing and and Harry fore some and and to the said Harry quid and and ther somed and Harry fing one the sing to fas and and to the fore said Harry fored and and aing to fore stught youl
# 20:55:23 End of epoch 41 , loss= 1.7777072191238403
#  Muggle as for the for quite and the stand said Harry, still and and the was place asled the studen the quite said stark the stan Muggle at said Harry!"
#
# Hermione and Harry, said was and and the pulled and a quite the staked and the first and the purple as and the going at the for the said the was
# 20:55:38 End of epoch 42 , loss= 1.692091703414917
#  for for she they said way.
#
# "They said at and as for the for the for the just and Harry quited and the was they said a quite for the for the said a quiter and the for Malfoy and the said and they for the forget of them.
#
# "Pomes at Mr. But asked the pulled they was to the was as stand and and the
# 20:55:53 End of epoch 43 , loss= 1.8694286346435547
#  Muggle for Harry staing and the pinking the for the for the forget they was and and and the something of the Gryffindore the past the Gryffindorm and as fiell and the fire of the Gryffindorm of the did at the the forget the for the said and the forget they way could the for the staid and Harry, sta
# 20:56:08 End of epoch 44 , loss= 1.8749221563339233
#  Muggle as face studention the some to stark and Harry, side and the for the the stand Harry, Pomesside as Muggle and Gryffindorm of the going at and the past and the for the staing the for stain. "But yeard Ron and and the for said Harry quiter father the said and and and the for the for the just t
# 20:56:23 End of epoch 45 , loss= 1.7992647886276245
#  Malfoy, Pomfere said Mr. Gonage the said Harry, squie face studentions the said a staid the past the Gryffindorm and the for the for the said and the past and the said a stain.
#
# "Hermione said Hermione stark and the for the stain. He was paink and and the for stain. Hermione starry, staid and the
# 20:56:40 End of epoch 46 , loss= 1.9641865491867065
#  Muggle as face some the Gryffindorm of the pointions; were was poing and the said and Harry, Pofessor McGonagall of the Gryffindorm and the pointion.
#
# "Yes, and Ron and as see in the Gryffindorm of the said the for Mr. Pofessor McGonagall of the Gryffindorm and the pointion.
#
# "Yes, and Ron and as
# 20:56:56 End of epoch 47 , loss= 1.9197007417678833
#  Muggle said Harry starry, way, and and and the past and Harry.
#
# "Well and a the still strany the Gryffindorm of the said and and the said and Harry, staing the for the first and Voldemore the still and Harry, stant of the Gryffindorry, "said Ron, squie the was quite any staing the find they said H
# 20:57:11 End of epoch 48 , loss= 1.8434679508209229
#  Muggle some said Harry, strant on and Harry said and and the for purpled them.
#
# "No, said Gryffindorm and Harry, Malfoy and and strany fife was for the just and Harry found and Harry purpring and and the for strany staing the first and the purple stain.
#
# "Now as and Ron and for pointione of the p
# 20:57:26 End of epoch 49 , loss= 1.8700999021530151
#  Muggle as for the for the fire you and the fire was and the was the said a staid and the for past and the for the stantion.
#
# "Yes, and as say, "But year, staid the was quiter and the for forge they was and and and the something as a suddention; a scome the studenly.
#
# "I was a was and and the for
# 20:57:41 End of epoch 50 , loss= 1.871016502380371
#  Muggle as all as studer the for pain.
#
# "Potter!" said Harry said Ron, whith was for and and as face to sturing the sturing to said a way, they're said and and the said a started the stranged the studenly said Ron and as placked and But the for the said and Harry, she something and see said Ron, sq
# 20:57:57 End of epoch 51 , loss= 1.8480899333953857
#  Muggle as for stople the Gryffindorm of the didn't said and where said and Harry, she past of the the stairs. Fanything and a said and and as for the for the for the just and Harry, Potter, Malfoy," said Harry, Pomessor McGonagall as started the gready and the for the said and the past and Harry, s
# 20:58:13 End of epoch 52 , loss= 1.9993228912353516
#
# "Rean, were as suddent and silve for startion. He said said Malfoy.
#
# "I say, "I said Gryffindorm and the past and Harry, Pomess
# 21:01:01 End of epoch 63 , loss= 1.9893958568572998
#  Muggle as and the for quite for put the first all and the was and But and Gryffindorm of the the Malfoy, "I said Harry, said Potter, Malfoy," said Harry, Pomessor McGonagall and said the forge they for and them.
#
# "I said Hermione start, just the said a said Malfoy, "said Harry, Potter, Malfoy," sa
# 21:01:17 End of epoch 64 , loss= 1.885759949684143
#  Muggle and Harry, she was pulled and as a stark, "said Harry.
#
# "It's all as all year," said Harry.
#
# "It's and as all painting the place; stain the was the said and Harry.
#
# "Ron and and Hermione just of the past as Muggle the said Harry, said and the was for the said and them.
#
# "Well and and Har
# 21:01:33 End of epoch 65 , loss= 1.832617998123169
#  Muggle and Harry, for of the was as the quite forget as staid Ron, "said Uncle Vold said "Hermione said Harry, and on the for the for them. Even and and a fiell of the studdenly and the greather.
#
# "He said Ron and and Harry, quite for forge them.
#
# "He said Gryffindorm of the door.
#
# "It's all ask
# 21:01:48 End of epoch 66 , loss= 1.8769079446792603
#  Muggle as all as studer just them.
#
# "No, Bane was quite stain."
#
# "Yes, and Ron, squite the said see the starting and the for the started and the past and Harry, Potter, Malfoy Harry, was and But and the was quite and the storm and and Gryffindorm of the didn't said and was they fiell as forge to
# 21:02:03 End of epoch 67 , loss= 1.870294213294983
#  Muggle as all as studdent the for strany stary, "Malfoy, "Ron, and Harry, said he place."
#
# "Nothink a stark and Harry, Potter, Malfoy," said Harry, Pomessor McGonagall and said the forge they stared and Ron and seemed the Gryffindorry. "He suddenly and Gryffindorm of the the forge them.
#
# "He sudd
# 21:02:18 End of epoch 68 , loss= 1.955201268196106
#  Mus. "Now, said a said Harry, staid and Harry, studdentions a still as studdenly.
#
# "Find as all as for Malfoy, "said Harry, Pomessor McGonagall as started they staid a the past But -- was the past and But -- the was as and said a the first they stary, and Ron and and But they were -- and Harry, sa
# 21:02:34 End of epoch 69 , loss= 1.8696796894073486
#  Muggle as for as studer just the said Ron and and Harry.
#
# "It's all and Harry, they was and By the was for put all the forge the said Harry, squie face the for quite as all as face studdenly and Gryffindorm and the Gryffindor and the was Malfoy, "I said Harry.
#
# "And Gryffindor for the was; Hermio
# 21:02:50 End of epoch 70 , loss= 1.9160974025726318
#  Muggle said Weasley. "Yes," said Harry! Twere Mr. Pomessor Madd and Gryfindorm of the good at for the for the for them.
#
# "No, Harry!
#
# "The was at Harry," said Harry.
#
# "He said Harry, squumpiled and and No Malfoy said Malfoy, just the said a said you the stranger.
#
# "Any was all year, stair Ron,
# 21:03:06 End of epoch 71 , loss= 1.8289721012115479
#  Muggle asked and Harry.
#
# "He suddenly and where studdenly.
#
# "Goodd a said Harry, said Harry, Potter, and with and and and and what of the said and and the past and Harry.
#
# "The was all as and the said a staid and Harry.
#
# "And Gryffindor the the was; Hermione and and and and the something and an
# 21:03:21 End of epoch 72 , loss= 1.8767683506011963
#  sill she place of the Gryffindorm and the passed at the passed Malfoy, "said Harry, squie found the stoped the for put them.
#
# "Oh, "said Freath, was I said Ron and and Harry, purpled and them.
#
# "Nother was all and and they was a said and and the passed as for quite the for the for the was and and
# 21:03:36 End of epoch 73 , loss= 1.8861443996429443
#  Muggle as and as studer Gryffindor the the said Harry.
#
# "Found and as Malfoy, "I said Ron and the past and Harry, Potter, and and was and the was quite and and and the pointion the for the said and and the packed at the Gryffindor and Harry, and Ron and and the fire forget of the pass and and and
# 21:03:51 End of epoch 74 , loss= 1.8097565174102783
#  Muggle said Harry, Potter, McGonan't and said and the pointion the for past and the Gryffindor and Harry, said and Gryffindorm of the passed the stant Harry, Potter, McGonagall Potter, But -- the Slythere said Harry, squumpled and the said the Gryffindorm off the Gryffindor and the was Malfoy, "I s
# 21:04:07 End of epoch 75 , loss= 1.794091820716858
#  Muggle as and as student as feway.
#
# "Yes, and Hermione said Gryffindorm and the Gryffindorm of the we they forgething them. He said and and and the forgether as the staid Ron, "said Harry.
#
# "And Gryffindorm of the we and and and and the said the Gryffindorm of the was at the could and and at forg
# 21:04:24 End of epoch 76 , loss= 1.9267349243164062
#  Muggle as all as studer just them.
#
# "No," said Harry!"
#
# "Well, "said Harry," said Ron and Harry, she pointion the place strant. Forge the was Malfoy, "said Harry, squeate the was pointion.
#
# "Yes, and as as for McGonagall and the strain. "Fin, Gryffindor as Malfoy started the going Ron and the sa
# 21:04:39 End of epoch 77 , loss= 1.6925736665725708
#  Malfoy, Potter!"
#
# "You said Potter, Potter!" said Harry suddenly and the was pointion the quite stain a squill the face, staid Ron, sturied a staid the pointion the for the staid Ron and the sturpled and and were strant Harry, something just started at started at Harry, were the was and and and th
# 21:04:54 End of epoch 78 , loss= 1.835655927658081
#  Malfoy, Potter!"
#
# "Yes, and Harry strain, were sturied and and and the said foor the for the for the said and Harry.
#
# "Ron and and Harry, side again, and the strain.
#
# "The said Harry, and Gryffindor Course Fill and and and the said Harry foor puse the pointion.
#
# "Yes, and Harry, said and Harry
# 21:05:09 End of epoch 79 , loss= 1.8145058155059814
#  Muggle as all as studdent the first; the studenly and the pass all suddent of the past and Harry," said Harry.
#
# "Well and as leate you was; Malfoy booked a stand the was for the for the for they and and Harry, just of the Gryffindor and as to the Gryffindor and Harry.
#
# "It's all as the for the st
# 21:05:24 End of epoch 80 , loss= 1.7439579963684082
#  Hermione was and and and the still for the just all and the started at Malfoy call and the was to the for the for the for the for they of the Gryffindorm and all and the was Malfoy, "I said Ron, they're said Harry, Pomessor McGonagally and the was Malfoy, "said Harry, Potter, Malfoy Harry, said and
# 21:05:40 End of epoch 81 , loss= 1.8905904293060303
#  Malfoy, Potter!"
#
# "Yes, and Harry quite and they pas the said and Harry, studding and the strand Harry.
#
# "I he was and But and Malfoy, Potter, just the staid Ron and and Harry, pointion the purple and them. Gryffindor and as in a stand the packer. "They said Ron, "said Harry," said Harry, said an
# 21:05:56 End of epoch 82 , loss= 1.8505361080169678
#  Malfoy," said Harry, squie forget the stair Ron and and and the something as and the stared stair for the stairs, and Harry, stary, Potter!" said Harry starry, just and the said the was pointion and the something as and the stared stair for the stairs, and Harry, stary, Potter!" said Harry starry,
# 21:06:12 End of epoch 83 , loss= 1.895819067955017
#  Malfoy, Potter, just the purpled as started and the said the Gryffindor and the fieling to the first; they were as and the forged to and Funnything as silve still sixed stranger. "Yes, and Gryffindorring as see as still as starting to started at Malfoy.
#
# "The said Harry, squiter as quite stain the
# 21:06:27 End of epoch 84 , loss= 1.8431365489959717
#  the for the for the forget at and the for McGonagally.
#
# "It said Ron the first all and and the said a stop and the for pup for the forget at and the Gryffindor and the was forget and the Gryffindorm and the pointion."
#
# "Wears all as you way, they was the forget and the past Bood and and the forge
# 21:06:42 End of epoch 85 , loss= 1.920952320098877
#  Malfoy, Potter, just the for the said and and the past all and the past they forget the started at started as the forget as as Everying as started as Malfoy. "I said Ron and they said and the pointion the for the for Madam Pomefere Mr. Potter, "said Harry, said Harry, Malfoy, "said as as Called and
# 21:06:57 End of epoch 86 , loss= 1.8327209949493408
#  Malfoy, Pofessor Quirrell and Ron and Breather; staid Hermione of the past Bood and But Quirrell aske the was forger and the fiell of the said Harry, said and the past the fier for a staid Ron and the past and Harry, Potter!"
#
# "A suddenly as started and Harry, pointion was the past But Quirrell as
# 21:07:13 End of epoch 87 , loss= 1.9421204328536987
#  Malfoy, Potter, just the stair for and and and the silver for suddenly.
#
# "So the was as studer the studenly.
#
# "Potter the staid Ron and and Harry, pointions and the was pumply."
#
# "I the said Quirrell as sill and them.
#
# "See was all as for Voldemort as the gointion."
#
# "Oh, whiting as fame -- th
# 21:07:29 End of epoch 88 , loss= 1.7393007278442383
#  Malfoy, Potter, just the for Quirrell as staid the stair and Gryffindor. Neville a was; a day the quite they forger the strand as and Beathing and and the was stark.
#
# "A said Gryffindore the the pointing the past and Beardy started as the pass and and as quite to face the the pass and all as start
# 21:07:45 End of epoch 89 , loss= 1.7933566570281982
#  Malfoy, Potter, Potter! Dumbledore was up and Gryffindor had suddenly and the Gryffindor and the was forge at and the fieling and the still as started as the stranger. "The said a said Ron, squite the first; Everying to the forge them.
#
# "I was all all and the said a staid and the for pointions. He
# 21:08:00 End of epoch 90 , loss= 1.9190822839736938
#  Malfoy, Potter, just the said Ron and and painted the for the Gryffindor and the was for the was the past and Harry face and and the started at started at Malfoy.
#
# "The said Harry's quumpilled and a stand the was started at the pass the was and and and the stark; a quite the for the for the for th
# 21:08:15 End of epoch 91 , loss= 1.879908800125122
#  Malfoy, Potter, Potter!"
#
# "A suddenting as start, Harry, side and the was pust and and was pulled and and was the said Ron and the pass and Hermione was for the for them. Even and and all of the forge them.
#
# "It's all as the stumpled as them.
#
# "No, said Gryfindor Malfoy, "I just all Breathing an
# 21:08:30 End of epoch 92 , loss= 1.8006809949874878
#  Malfoy, Potter, just the start Mr. Potter, and the was for the first; a staid was the start and and and with the forget and and Harry. They was and and and the stance as all see studdenly strange at started at Harry, were studdenly and them was and and was pulled and the was for started at the past
# 21:08:46 End of epoch 93 , loss= 1.9705218076705933
#  Muggle and Harry said Gryffindorm of the the Malfoy, and where -- was and and and the said fiffindor the said and and and the was found Gryffindorm and as all and the Gryffindorm of the get as the the forge them.
#
# "He said Gryffindorm of the said the Slythere was and and and Gryffindorm of the pas
# 21:09:03 End of epoch 94 , loss= 1.810399055480957
#  Malfoy, Potter," said Potter, Malfoy Harry, said and them.
#
# "And Gryffindor forge the was and and and said quite to find the for the forget of Everying a Slyther!" said Harry, and Harry, put with was a said and and the forget at as Everying and Ron and But I was a stail for the started at and the
# 21:09:18 End of epoch 95 , loss= 1.8733693361282349
#  Malfoy, Potter, just the for the stand and Hermione was and and and the something around and and and the for the for them. Even and and around and and with the for quite and and and of the for them.
#
# "No, you Mr. No, Malfoy and around the first; Everying at said Harry, Potter, Malfoy," said Harry,
# 21:09:33 End of epoch 96 , loss= 1.6866313219070435
#  the for the for the for them. Every for was all and all of the greather.
#
# "I said was all all and the studdenly and Gryffindor. He said Gryffindor sure the Gryffindor and the was Malfoy, "I said Ron and all and sife the just the Gryffindor and as staid the for the started and and the started the w
# 21:09:48 End of epoch 97 , loss= 1.7079730033874512
#  Malfoy, Potter, just the stair strain.
#
# "It's said Harry, Pomfessor McGonagall and said the forge the past Harry.
#
# "They were was all and said Harry, Potter Potter, Malfoy stary, "said Harry.
#
# "Well -- and see a squite said Harry, squup up of the them. I said Hermione studention."
#
# "Yes," said
# 21:10:03 End of epoch 98 , loss= 1.9018054008483887
#  the for the for the for them. Everying at and all the said the Gryffindor.
#
# "He said Gryffindor the the pointion a call as startion. Weasley, and and all somether.
#
# "No, "The was all as all Voldemort, stanter strand and and the something and said and the something and Harry, side and and and the
# 21:10:20 End of epoch 99 , loss= 1.6883201599121094
#  Malfoy, Potter, just the stair straid Ron and the past and Harry quite said and the the said Hermione said Harry, said Harry, squied for the for put the forget as and and and the sorm face of the Gryffindor for the said and Hermione was and and was the said a stopped the stoped the for the was the
# 21:10:36 End of epoch 100 , loss= 1.847263216972351
#  Muggle and Harry, shought, said as and the stand Harry, squite for for furying the for strain.
#
# "Yes, and Harry!"
#
# "Yes, "said Ron, "said Harry," Ron, Harry!" said Harry.
#
# "Well and as looked they said Ron and and Harry, side and the was the said and Harry.
#
# "And you was all forget as the the S

# %%
# ==================== User interaction ==================== #

while True:
    text = input("> ").strip()
    if text == "":
        continue
    if text == "exit":
        break
    char_list = list(text[-MAXLEN:])
    # Generate 50 characters starting from the input text
    try:
        print(text, end='')
        for i in range(50):
            input_tensor = torch.tensor([char_to_id[c] for c in char_list] + [
                                        char_to_id[PADDING_SYMBOL]]*(MAXLEN-len(char_list))).unsqueeze(0).to(device)
            logits = charlm(input_tensor).squeeze().to(device)
            _, new_character_tensor = logits.topk(1)
            new_character = id_to_char[new_character_tensor.detach().item()]
            print(new_character, end='')
            if len(char_list) == MAXLEN:
                char_list.pop(0)
            char_list.append(new_character)
        print()
    except KeyError:
        continue
# Out:
# Harry stain, Madd Poter, I stan't looked the Gryffindor
# Hermione and Harry, said Muggle some and the Gryffindore as the was
# Hermione stain, Madd Goy just. It all of the study them.
#
# The boy started and Malfor Malfoy, and and them. Gryffind
